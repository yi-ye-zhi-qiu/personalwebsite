# %%
import numpy as np
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import numpy as np
import json
import re 
import time
from pandas.io.json import json_normalize

# %%
match_df = pd.read_pickle('/Users/liamisaacs/Desktop/github repositories/personalwebsite/data/match_data_version1.pickle')
winner_df =  pd.read_pickle('/Users/liamisaacs/Desktop/github repositories/personalwebsite/data/match_winner_data_version1.pickle')
loser_df = pd.read_pickle('/Users/liamisaacs/Desktop/github repositories/personalwebsite/data/match_loser_data_version1.pickle')

# %%
match_df
# Out:
#     gameCreation  gameDuration        gameId gameMode      gameType  \
# 0   1.585155e+12        1323.0  4.247263e+09  CLASSIC  MATCHED_GAME
# 1   1.585152e+12        1317.0  4.247156e+09  CLASSIC  MATCHED_GAME
# 2   1.585059e+12         932.0  4.243963e+09  CLASSIC  MATCHED_GAME
# 3   1.584978e+12        2098.0  4.241678e+09  CLASSIC  MATCHED_GAME
# 4   1.584973e+12        2344.0  4.241539e+09  CLASSIC  MATCHED_GAME
# ..           ...           ...           ...      ...           ...
# 0   1.579163e+12        1029.0  4.088497e+09      URF  MATCHED_GAME
# 0   1.580823e+12        1544.0  4.130964e+09  CLASSIC  MATCHED_GAME
# 0   1.580382e+12        2090.0  4.119954e+09  CLASSIC  MATCHED_GAME
# 0   1.580805e+12        1382.0  4.130440e+09      URF  MATCHED_GAME
# 0   1.584505e+12        1432.0  4.225861e+09     ARAM  MATCHED_GAME
#
#       gameVersion  mapId                              participantIdentities  \
# ...

# %%
json_normalize(match_df['participants'].iloc[0][0])
# Out:
# <ipython-input-6-cde6cf9ef0ee>:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   json_normalize(match_df['participants'].iloc[0][0])
#    participantId  teamId  championId  spell1Id  spell2Id  stats.participantId  \
# 0              1     100           7         1         4                    1
#
#    stats.win  stats.item0  stats.item1  stats.item2  ...  \
# 0      False         2033         3285         3108  ...
#
#    timeline.creepsPerMinDeltas.10-20  timeline.creepsPerMinDeltas.0-10  \
# 0                                6.2                               6.1
#
#    timeline.xpPerMinDeltas.10-20  timeline.xpPerMinDeltas.0-10  \
# 0                          473.5                         386.6
#
#    timeline.goldPerMinDeltas.10-20  timeline.goldPerMinDeltas.0-10  \
# 0                              277                           315.6
#
#    timeline.damageTakenPerMinDeltas.10-20  \
# 0                                     906
#
# ...

# %%
match_df['participants'].iloc[0][0]['stats']
# Out:
# {'participantId': 1,
#  'win': False,
#  'item0': 2033,
#  'item1': 3285,
#  'item2': 3108,
#  'item3': 1082,
#  'item4': 3020,
#  'item5': 2055,
#  'item6': 3364,
#  'kills': 3,
#  'deaths': 6,
#  'assists': 3,
#  'largestKillingSpree': 2,
#  'largestMultiKill': 1,
#  'killingSprees': 1,
#  'longestTimeSpentLiving': 564,
#  'doubleKills': 0,
#  'tripleKills': 0,
#  'quadraKills': 0,
#  'pentaKills': 0,
#  'unrealKills': 0,
#  'totalDamageDealt': 71369,
#  'magicDamageDealt': 56332,
#  'physicalDamageDealt': 13037,
#  'trueDamageDealt': 1999,
#  'largestCriticalStrike': 0,
#  'totalDamageDealtToChampions': 10844,
#  'magicDamageDealtToChampions': 8926,
#  'physicalDamageDealtToChampions': 1918,
#  'trueDamageDealtToChampions': 0,
#  'totalHeal': 4006,
#  'totalUnitsHealed': 1,
#  'damageSelfMitigated': 6742,
#  'damageDealtToObjectives': 1055,
#  'damageDealtToTurrets': 1008,
#  'visionScore': 14,
#  'timeCCingOthers': 12,
#  'totalDamageTaken': 17255,
#  'magicalDamageTaken': 5282,
# ...

# %%
winner_df
# Out:
#         teamId  win  firstBlood  firstTower  firstInhibitor  firstBaron  \
# 0          200  Win       False        True            True       False
# 1          100  Win       False       False           False       False
# 2          200  Win        True        True            True       False
# 3          200  Win        True        True           False       False
# 4          100  Win        True        True            True        True
# ...        ...  ...         ...         ...             ...         ...
# 108824     100  Win       False        True            True        True
# 108825     100  Win        True       False           False        True
# 108826     100  Win       False       False           False        True
# 108827     100  Win        True        True            True       False
# 108828     100  Win       False        True           False       False
#
#         firstDragon  firstRiftHerald  towerKills  inhibitorKills  baronKills  \
# ...
